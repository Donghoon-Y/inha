# %% [markdown]
# # Root locus
#
# $$
# \newcommand{\eg}{{\it e.g.}}
# \newcommand{\ie}{{\it i.e.}}
# \newcommand{\argmin}{\operatornamewithlimits{argmin}}
# \newcommand{\mc}{\mathcal}
# \newcommand{\mb}{\mathbb}
# \newcommand{\mf}{\mathbf}
# \newcommand{\minimize}{{\text{minimize}}}
# \newcommand{\diag}{{\text{diag}}}
# \newcommand{\cond}{{\text{cond}}}
# \newcommand{\rank}{{\text{rank }}}
# \newcommand{\range}{{\mathcal{R}}}
# \newcommand{\null}{{\mathcal{N}}}
# \newcommand{\tr}{{\text{trace}}}
# \newcommand{\dom}{{\text{dom}}}
# \newcommand{\dist}{{\text{dist}}}
# \newcommand{\R}{\mathbf{R}}
# \newcommand{\SM}{\mathbf{S}}
# \newcommand{\ball}{\mathcal{B}}
# \newcommand{\bmat}[1]{\begin{bmatrix}#1\end{bmatrix}}
# $$

# %% [markdown]
# __<div style="text-align: right"> ASE3093: Automatic control, Inha University. </div>__
# _<div style="text-align: right"> Jong-Han Kim (jonghank@inha.ac.kr) </div>_

# %%
# !pip install control
# Out:
# Requirement already satisfied: control in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from control) (2.2.5)
# Requirement already satisfied: scipy>=1.8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from control) (1.15.3)
# Requirement already satisfied: matplotlib>=3.6 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from control) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.6->control) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.6->control) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.6->control) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.6->control) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/hoony/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.6->control) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.6->control) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.6->control) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hoony/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.6->control) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/hoony/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.6->control) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from control.matlab import *

# %%
num = np.array([1])
den = np.array([1, 1, 0])
G = tf(num, den)

ar = 2
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
num = np.array([1,2])
den = np.array([1,4,0,0])
G = tf(num, den)

ar = 10
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
zeros = [9j, -9j, -5]
poles = [0, 0, 10j, -10j]
G = zpk(zeros, poles, 1)

ar = 20
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
zeros = [1]
poles = [2, 3, -10]
G = zpk(zeros, poles, 1)

ar = 20
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
zeros = [1]
poles = [2, 3, -10, -20]
G = zpk(zeros, poles, 1)

kvec_ = [0,10,200,1050]
rlist, klist = rlocus(G, kvec_,plot=False);
print(rlist)

ar = 20
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.plot(rlist[2].real, rlist[2].imag, "rx", label=f"K={kvec_[2]}")
plt.plot(rlist[3].real, rlist[3].imag, "gx", label=f"K={kvec_[3]}")
plt.legend()
plt.grid()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# [[-20.        +0.j         -10.        +0.j
#     2.        +0.j           3.        +0.j        ]
#  [-20.0412611 +0.j          -9.92963656+0.j
#     2.04089322+0.j           2.93000444+0.j        ]
#  [-20.74901846+0.j          -8.62980666+0.j
#     2.18941256-0.88948992j   2.18941256+0.88948992j]
#  [-22.98674803+0.j          -0.63492445+2.89391526j
#    -0.74340308+0.j          -0.63492445-2.89391526j]]

# %%
zr = [-3, 11j, -11j]
pl = [0, 0, 10j, -10j,-11,-11]
G = zpk(zr, pl, 1)

ar = 20
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
num = np.array([10])
den = np.array([1, 0, 110,0,0])
G = tf(num, den)

ar = 20
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
num = np.array([10, 30])
den = np.array([1, 0, 110,0,0])
G = tf(num, den)

ar = 20
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
zr = [-3, 10j, -10j]
pl = [0, 0, np.sqrt(110)*1j, -np.sqrt(110)*1j,-10,-10]
G = zpk(zr, pl, 1)

ar = 20
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
zr = [-3, 11j, -11j]
pl = [0, 0, np.sqrt(110)*1j, -np.sqrt(110)*1j,-11,-11]
G = zpk(zr, pl, 1)

ar = 20
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
zr = [2]
pl = [-12, 4, 6]
G = zpk(zr, pl, 1)

ar = 20
rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %%
zr = [-3,-1]
pl = [0.1,0,0, 0]
G = zpk(zr, pl, 1)

ar =1

rlocus(G)
fig = plt.gcf().set_size_inches(8, 8)
plt.xlim([-ar, ar]), plt.ylim([-ar, ar])
plt.grid(True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/control/rlocus.py:210: FutureWarning: root_locus() return value of roots, gains is deprecated; use root_locus_map()
#   warnings.warn(
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
